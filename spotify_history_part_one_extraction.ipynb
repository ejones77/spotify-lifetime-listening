# %% [markdown]
# # Seven years of Spotify Part One: Extraction

# %% [markdown]
# Lately, I've been curious about my personal listening habits. Spotify has an automated tool that delivers personal streaming data from the past year, but I wished to see it all.
#
# All I had to do was send an email to privacy@spotify.com requesting my extended streaming history. That process, and the description of what data you'll recieve, is [available here](https://support.spotify.com/us/article/data-rights-and-privacy-settings/).
#
# This notebook begins my journey to explore my music taste. Part One encompasses loading in data for everything I've listened to on Spotify since 2015, and using [Spotify's API](https://developer.spotify.com/documentation/web-api/quick-start/), as well as the [well-documented](https://spotipy.readthedocs.io/en/master/#) library, Spotipy, to gather a wide range of metrics surrounding each track, artist, and album.
#
# In the end, we'll have a dataset ready to be analyzed.

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
cid = 'XXXX'
secret = 'XXXX'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
tracks = pd.concat(
    map(pd.read_json, ['spotify_life/endsong_0.json', 
    'spotify_life/endsong_1.json', 
    'spotify_life/endsong_2.json', 
    'spotify_life/endsong_3.json', 
    'spotify_life/endsong_4.json', 
    'spotify_life/endsong_5.json', 
    'spotify_life/endsong_6.json', 
    'spotify_life/endsong_7.json', 
    'spotify_life/endsong_8.json', 
    'spotify_life/endsong_9.json', 
    'spotify_life/endsong_10.json']), ignore_index=True)
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179546 entries, 0 to 179545
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 179546 non-null  object
#  1   username                           179546 non-null  object
#  2   platform                           179546 non-null  object
#  3   ms_played                          179546 non-null  int64
#  4   conn_country                       179546 non-null  object
#  5   ip_addr_decrypted                  179546 non-null  object
#  6   user_agent_decrypted               179546 non-null  object
#  7   master_metadata_track_name         179044 non-null  object
#  8   master_metadata_album_artist_name  179044 non-null  object
#  9   master_metadata_album_album_name   179044 non-null  object
#  10  spotify_track_uri                  179044 non-null  object
#  11  episode_name                       502 non-null     object
#  12  episode_show_name                  502 non-null     object
#  13  spotify_episode_uri                502 non-null     object
#  14  reason_start                       179546 non-null  object
#  15  reason_end                         179546 non-null  object
#  16  shuffle                            179546 non-null  bool
#  17  skipped                            33833 non-null   float64
#  18  offline                            179546 non-null  bool
#  19  offline_timestamp                  179546 non-null  int64
#  20  incognito_mode                     179546 non-null  bool
# dtypes: bool(3), float64(1), int64(2), object(15)
# memory usage: 25.2+ MB

# %%
tracks.describe()
# Out:
#           ms_played       skipped  offline_timestamp
# count  1.795460e+05  33833.000000       1.795460e+05
# mean   1.125443e+05      0.655514       1.101390e+12
# std    1.386337e+05      0.475207       7.362376e+11
# min    0.000000e+00      0.000000       0.000000e+00
# 25%    1.462000e+03      0.000000       0.000000e+00
# 50%    7.541550e+04      1.000000       1.551370e+12
# 75%    2.109060e+05      1.000000       1.627057e+12
# max    5.813188e+06      1.000000       1.663170e+12

# %% [markdown]
# ## Extracting data for tracks

# %% [markdown]
# The bulk of the work here hinges upon Spotify URI's, or Uniform Resource Indicators. They function as a primary key for every song, track, or album.
#
# We will use all three throughout this notebook.

# %%
unique_track_uris = tracks['spotify_track_uri'].dropna().unique()

def extract_sp_data(unique_uris, sp_method, chunksize):
    """Split a list of unique URIs into n chunks of lists, then perform a spotipy method on each chunk
    
    args: 
    unique_uris (list): unique uris to extract data for
    sp_method (func): an extraction method available in Spotipy
    chunksize (int): number of uris to include in each chunk, to separate the amount of api calls performed. 

    Returns: List of JSON objects for each track
    """

    uris_split = []
    for i in range(0, len(unique_uris), chunksize):
        uris_split.append(unique_uris[i:i+chunksize].tolist())


    item_info = []
    for uris in uris_split:
        item_info.append(sp_method(uris))
    return item_info

track_info = extract_sp_data(unique_track_uris, sp.tracks, 48)

# %%
track_info_df = pd.concat(
    map(lambda x: pd.json_normalize(x, record_path=['tracks']), [ls for ls in track_info]), ignore_index=True)
#making sure the artist identifiers also get their own columns, keeping first artist only
track_info_df['artists.name'] = track_info_df['artists'].str[0].str.get('name')
track_info_df['artists.uri'] = track_info_df['artists'].str[0].str.get('uri')
track_info_df.head()
# Out:
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2  [AD, AE, AG, AM, AO, AR, AT, AU, AZ, BB, BD, B...            1
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4                                               [US]            1
#
#    duration_ms  explicit                                               href  \
# 0       272293     False  https://api.spotify.com/v1/tracks/5DiXcVovI0Fc...
# 1       280520      True  https://api.spotify.com/v1/tracks/17dRP50Rx5Dd...
# 2       201760     False  https://api.spotify.com/v1/tracks/4OHnqedhcXex...
# 3       193733     False  https://api.spotify.com/v1/tracks/1oew3nFNY3vM...
# 4       259346     False  https://api.spotify.com/v1/tracks/5mQrrvxSTuqP...
#
#                        id  is_local  \
# 0  5DiXcVovI0FcY2s0icWWUu     False
# 1  17dRP50Rx5DdSH9Qy4xR9A     False
# 2  4OHnqedhcXexo7f2a5RiZY     False
# 3  1oew3nFNY3vMacJAsvry0S     False
# 4  5mQrrvxSTuqPzLUtaVNtnN     False
#
#                                         name  popularity  ...  \
# 0                                  Mr. Jones          78  ...
# 1  American Terrorist (feat. Matthew Santos)          34  ...
# 2              Walk on the Moon (feat. Lynx)          40  ...
# 3                     Me And My Broken Heart          79  ...
# 4                                  Emoticons          35  ...
#
#                       album.name  album.release_date  \
# 0    August And Everything After          1993-01-01
# 1    Lupe Fiasco's Food & Liquor          2006-06-27
# 2  Walk on the Moon (feat. Lynx)          2018-03-06
# 3                   Let The Road          2014-01-01
# 4    Glitterbug (Deluxe Edition)          2015-04-14
#
#   album.release_date_precision album.total_tracks album.type  \
# 0                          day                 11      album
# 1                          day                 16      album
# 2                          day                  1      album
# 3                          day                 10      album
# 4                          day                 13      album
#
#                               album.uri external_ids.isrc  \
# 0  spotify:album:4nKfZbCALT9H9LfedtDwnZ      USIR10000287
# 1  spotify:album:0TDJRkEr2SrhWTetdkEzED      USAT20620108
# 2  spotify:album:3rAZDcr1bEh85GiD8UoPPW      TCADM1867865
# 3  spotify:album:02ae5i5UAoFrt2peVox9Xd      USUM71401800
# 4  spotify:album:0n5sLhq91buJwIW4j3Ji0I      GBAHT1400472
#
#                                external_urls.spotify    artists.name  \
# 0  https://open.spotify.com/track/5DiXcVovI0FcY2s...  Counting Crows
# 1  https://open.spotify.com/track/17dRP50Rx5DdSH9...     Lupe Fiasco
# 2  https://open.spotify.com/track/4OHnqedhcXexo7f...    Luke Mitrani
# 3  https://open.spotify.com/track/1oew3nFNY3vMacJ...          Rixton
# 4  https://open.spotify.com/track/5mQrrvxSTuqPzLU...     The Wombats
#
#                              artists.uri
# 0  spotify:artist:0vEsuISMWAKNctLlUAhSZC
# 1  spotify:artist:01QTIT5P1pFP3QnnFSdsJf
# 2  spotify:artist:6OzAqsb9KgjKjUyoTjZ6UV
# 3  spotify:artist:0kkxsdcaWmWU2yWAqclDh4
# 4  spotify:artist:0Ya43ZKWHTKkAbkoJJkwIB
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Extracting Audio Features

# %%
audio_features_list = extract_sp_data(unique_track_uris, sp.audio_features, 50)
audio_features_df = pd.concat(
    map(pd.json_normalize, [ls for ls in audio_features_list]), ignore_index=True)
audio_features_df.head()
# Out:
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.578   0.817   0.0    -6.542   1.0       0.0363       0.18300
# 1         0.614   0.959   1.0    -3.514   1.0       0.0930       0.01680
# 2         0.810   0.637  11.0    -8.029   1.0       0.0424       0.01660
# 3         0.545   0.783   5.0    -4.261   0.0       0.0345       0.00489
# 4         0.610   0.708  11.0    -4.300   0.0       0.0606       0.00950
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000003     0.285    0.726  141.621  audio_features
# 1          0.000000     0.312    0.484   83.264  audio_features
# 2          0.000001     0.112    0.622  106.938  audio_features
# 3          0.000000     0.132    0.551  174.084  audio_features
# 4          0.000031     0.116    0.508  101.003  audio_features
#
#                        id                                   uri  \
# 0  5DiXcVovI0FcY2s0icWWUu  spotify:track:5DiXcVovI0FcY2s0icWWUu
# 1  17dRP50Rx5DdSH9Qy4xR9A  spotify:track:17dRP50Rx5DdSH9Qy4xR9A
# 2  4OHnqedhcXexo7f2a5RiZY  spotify:track:4OHnqedhcXexo7f2a5RiZY
# 3  1oew3nFNY3vMacJAsvry0S  spotify:track:1oew3nFNY3vMacJAsvry0S
# 4  5mQrrvxSTuqPzLUtaVNtnN  spotify:track:5mQrrvxSTuqPzLUtaVNtnN
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5DiXcVovI0Fc...
# 1  https://api.spotify.com/v1/tracks/17dRP50Rx5Dd...
# 2  https://api.spotify.com/v1/tracks/4OHnqedhcXex...
# 3  https://api.spotify.com/v1/tracks/1oew3nFNY3vM...
# 4  https://api.spotify.com/v1/tracks/5mQrrvxSTuqP...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5DiX...     272293.0
# 1  https://api.spotify.com/v1/audio-analysis/17dR...     280520.0
# 2  https://api.spotify.com/v1/audio-analysis/4OHn...     201760.0
# 3  https://api.spotify.com/v1/audio-analysis/1oew...     193733.0
# 4  https://api.spotify.com/v1/audio-analysis/5mQr...     259347.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %% [markdown]
# ## Extracting Artist info

# %%
unique_artist_uris = track_info_df['artists.uri'].unique()
artist_info = extract_sp_data(unique_artist_uris, sp.artists, 37)
artist_info_df = pd.concat(
    map(lambda x: pd.json_normalize(x, record_path=['artists']), [ls for ls in artist_info]), ignore_index=True)
artist_info_df.head()
# Out:
#                                               genres  \
# 0     [alternative rock, neo mellow, pop rock, rock]
# 1  [alternative hip hop, chicago rap, conscious h...
# 2                                          [nyc pop]
# 3          [dance pop, pop, pop rock, post-teen pop]
# 4               [liverpool indie, modern rock, rock]
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0vEsuISMWAK...  0vEsuISMWAKNctLlUAhSZC
# 1  https://api.spotify.com/v1/artists/01QTIT5P1pF...  01QTIT5P1pFP3QnnFSdsJf
# 2  https://api.spotify.com/v1/artists/6OzAqsb9Kgj...  6OzAqsb9KgjKjUyoTjZ6UV
# 3  https://api.spotify.com/v1/artists/0kkxsdcaWmW...  0kkxsdcaWmWU2yWAqclDh4
# 4  https://api.spotify.com/v1/artists/0Ya43ZKWHTK...  0Ya43ZKWHTKkAbkoJJkwIB
#
#                                               images            name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Counting Crows
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Lupe Fiasco
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Luke Mitrani
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...          Rixton
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...     The Wombats
#
#    popularity    type                                    uri  \
# 0          68  artist  spotify:artist:0vEsuISMWAKNctLlUAhSZC
# 1          66  artist  spotify:artist:01QTIT5P1pFP3QnnFSdsJf
# 2          41  artist  spotify:artist:6OzAqsb9KgjKjUyoTjZ6UV
# 3          62  artist  spotify:artist:0kkxsdcaWmWU2yWAqclDh4
# 4          66  artist  spotify:artist:0Ya43ZKWHTKkAbkoJJkwIB
#
#                                external_urls.spotify followers.href  \
# 0  https://open.spotify.com/artist/0vEsuISMWAKNct...           None
# 1  https://open.spotify.com/artist/01QTIT5P1pFP3Q...           None
# 2  https://open.spotify.com/artist/6OzAqsb9KgjKjU...           None
# 3  https://open.spotify.com/artist/0kkxsdcaWmWU2y...           None
# 4  https://open.spotify.com/artist/0Ya43ZKWHTKkAb...           None
#
#    followers.total
# 0          1586363
# 1          1817005
# 2             8793
# 3           739070
# 4          1026603

# %% [markdown]
# ## Extracting album info

# %%
unique_album_uris = track_info_df['album.uri'].unique()
album_info = extract_sp_data(unique_album_uris, sp.albums, 20)
album_info_df = pd.concat(
    map(lambda x: pd.json_normalize(x, record_path=['albums']), [ls for ls in album_info]), ignore_index=True)
album_info_df.head()
# Out:
#   album_type                                            artists  \
# 0      album  [{'external_urls': {'spotify': 'https://open.s...
# 1      album  [{'external_urls': {'spotify': 'https://open.s...
# 2     single  [{'external_urls': {'spotify': 'https://open.s...
# 3      album  [{'external_urls': {'spotify': 'https://open.s...
# 4      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 2  [AD, AE, AG, AM, AO, AR, AT, AU, AZ, BB, BD, B...
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 4                                               [US]
#
#                                           copyrights genres  \
# 0  [{'text': '© 1993 DGC Records', 'type': 'C'}, ...     []
# 1  [{'text': '© 2006 Atlantic Recording Corporati...     []
# 2  [{'text': '2018 Frendly Presents', 'type': 'C'...     []
# 3  [{'text': '© 2014 School Boy/Giant Little Man/...     []
# 4  [{'text': '© 2015 Bright Antenna Records under...     []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/4nKfZbCALT9H...  4nKfZbCALT9H9LfedtDwnZ
# 1  https://api.spotify.com/v1/albums/0TDJRkEr2Srh...  0TDJRkEr2SrhWTetdkEzED
# 2  https://api.spotify.com/v1/albums/3rAZDcr1bEh8...  3rAZDcr1bEh85GiD8UoPPW
# 3  https://api.spotify.com/v1/albums/02ae5i5UAoFr...  02ae5i5UAoFrt2peVox9Xd
# 4  https://api.spotify.com/v1/albums/0n5sLhq91buJ...  0n5sLhq91buJwIW4j3Ji0I
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                              label                           name  ...  \
# 0                              DGC    August And Everything After  ...
# 1                 Atlantic Records    Lupe Fiasco's Food & Liquor  ...
# 2                 Frendly Presents  Walk on the Moon (feat. Lynx)  ...
# 3  Silent Records/Giant Little Man                   Let The Road  ...
# 4                   Bright Antenna    Glitterbug (Deluxe Edition)  ...
#
#    external_ids.upc                              external_urls.spotify  \
# 0    00720642452820  https://open.spotify.com/album/4nKfZbCALT9H9Lf...
# 1      075678395963  https://open.spotify.com/album/0TDJRkEr2SrhWTe...
# 2      859725358329  https://open.spotify.com/album/3rAZDcr1bEh85Gi...
# 3    00602537979912  https://open.spotify.com/album/02ae5i5UAoFrt2p...
# 4      856908004295  https://open.spotify.com/album/0n5sLhq91buJwIW...
#
#                                          tracks.href  \
# 0  https://api.spotify.com/v1/albums/4nKfZbCALT9H...
# 1  https://api.spotify.com/v1/albums/0TDJRkEr2Srh...
# 2  https://api.spotify.com/v1/albums/3rAZDcr1bEh8...
# 3  https://api.spotify.com/v1/albums/02ae5i5UAoFr...
# 4  https://api.spotify.com/v1/albums/0n5sLhq91buJ...
#
#                                         tracks.items tracks.limit tracks.next  \
# 0  [{'artists': [{'external_urls': {'spotify': 'h...           50        None
# 1  [{'artists': [{'external_urls': {'spotify': 'h...           50        None
# 2  [{'artists': [{'external_urls': {'spotify': 'h...           50        None
# 3  [{'artists': [{'external_urls': {'spotify': 'h...           50        None
# 4  [{'artists': [{'external_urls': {'spotify': 'h...           50        None
#
#   tracks.offset tracks.previous tracks.total external_ids.amgid
# 0             0            None           11                NaN
# 1             0            None           16                NaN
# 2             0            None            1                NaN
# 3             0            None           10                NaN
# 4             0            None           13                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Condensing into one dataframe

# %% [markdown]
# Of the three new dataframes, we'll want these columns to be joined with the first dataframe of lifetime listening data.
#
# - track_info_df: `uri`, `album.uri`, `artists.uri`, `popularity`, `duration_ms`, `album.album_type`, `album.release_date`
# - artist_info_df: `genres`, `popularity`, `followers.total`
# - album_info_df: `popularity`, `label`, `tracks.total`
# - audio_features_df: `uri`, `danceability`, `energy`, `key`, `loudness`, `mode`, `speechiness`, `acousticness`, `instrumentalness`, `liveness`, `valence`, `tempo`, `time_signature`
#
# Before we can work with the lifetime set, we'll want everything to get linked to the track_info_df, which hosts each item's unique ID (the URI)

# %%
track_info_cols = ['uri', 'album.uri', 'artists.uri', 'popularity', 'duration_ms', 'album.album_type', 'album.release_date']
artist_info_cols = ['uri', 'genres', 'popularity', 'followers.total']
album_info_cols = ['uri', 'popularity', 'label', 'tracks.total']
audio_features_cols = ['uri', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

track_info_reduced = track_info_df[track_info_cols].rename(columns={'uri':'track_uri', 'popularity':'track_popularity'})
artist_info_reduced = artist_info_df[artist_info_cols].rename(columns={'uri':'artists.uri', 'popularity':'artist_popularity'})
album_info_reduced = album_info_df[album_info_cols].rename(columns={'uri':'album.uri', 'popularity':'album_popularity'})
audio_features_reduced = audio_features_df[audio_features_cols].rename(columns={'uri':'track_uri'})

track_info_combined = track_info_reduced.merge(artist_info_reduced, on='artists.uri')
track_info_combined = track_info_combined.merge(album_info_reduced, on='album.uri')
track_info_combined = track_info_combined.merge(audio_features_reduced, on='track_uri')
track_info_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19305 entries, 0 to 19304
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_uri           19305 non-null  object
#  1   album.uri           19305 non-null  object
#  2   artists.uri         19305 non-null  object
#  3   track_popularity    19305 non-null  int64
#  4   duration_ms         19305 non-null  int64
#  5   album.album_type    19305 non-null  object
#  6   album.release_date  19305 non-null  object
#  7   genres              19305 non-null  object
#  8   artist_popularity   19305 non-null  int64
#  9   followers.total     19305 non-null  int64
#  10  album_popularity    19305 non-null  int64
#  11  label               19296 non-null  object
#  12  tracks.total        19305 non-null  int64
#  13  danceability        19305 non-null  float64
#  14  energy              19305 non-null  float64
#  15  key                 19305 non-null  float64
#  16  loudness            19305 non-null  float64
#  17  mode                19305 non-null  float64
#  18  speechiness         19305 non-null  float64
#  19  acousticness        19305 non-null  float64
#  20  instrumentalness    19305 non-null  float64
#  21  liveness            19305 non-null  float64
#  22  valence             19305 non-null  float64
#  23  tempo               19305 non-null  float64
#  24  time_signature      19305 non-null  float64
# dtypes: float64(12), int64(6), object(7)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Adding new features back into the dataframe of lifetime listening

# %%
full_tracks = tracks.merge(track_info_combined, left_on='spotify_track_uri', right_on='track_uri', how='left')
#dropping PII
full_tracks.drop(columns=['username', 'platform', 'conn_country', 'ip_addr_decrypted', 'user_agent_decrypted'], axis=1, inplace=True)
#dropping podcast cols
full_tracks.drop(columns=['episode_name', 'episode_show_name', 'spotify_episode_uri'], axis=1, inplace=True)
full_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179565 entries, 0 to 179564
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 179565 non-null  object
#  1   ms_played                          179565 non-null  int64
#  2   master_metadata_track_name         179063 non-null  object
#  3   master_metadata_album_artist_name  179063 non-null  object
#  4   master_metadata_album_album_name   179063 non-null  object
#  5   spotify_track_uri                  179063 non-null  object
#  6   reason_start                       179565 non-null  object
#  7   reason_end                         179565 non-null  object
#  8   shuffle                            179565 non-null  bool
#  9   skipped                            33837 non-null   float64
#  10  offline                            179565 non-null  bool
#  11  offline_timestamp                  179565 non-null  int64
#  12  incognito_mode                     179565 non-null  bool
#  13  track_uri                          179051 non-null  object
#  14  album.uri                          179051 non-null  object
#  15  artists.uri                        179051 non-null  object
#  16  track_popularity                   179051 non-null  float64
#  17  duration_ms                        179051 non-null  float64
#  18  album.album_type                   179051 non-null  object
#  19  album.release_date                 179051 non-null  object
#  20  genres                             179051 non-null  object
#  21  artist_popularity                  179051 non-null  float64
#  22  followers.total                    179051 non-null  float64
#  23  album_popularity                   179051 non-null  float64
#  24  label                              179040 non-null  object
#  25  tracks.total                       179051 non-null  float64
#  26  danceability                       179051 non-null  float64
#  27  energy                             179051 non-null  float64
#  28  key                                179051 non-null  float64
#  29  loudness                           179051 non-null  float64
#  30  mode                               179051 non-null  float64
#  31  speechiness                        179051 non-null  float64
#  32  acousticness                       179051 non-null  float64
#  33  instrumentalness                   179051 non-null  float64
#  34  liveness                           179051 non-null  float64
#  35  valence                            179051 non-null  float64
#  36  tempo                              179051 non-null  float64
#  37  time_signature                     179051 non-null  float64
# dtypes: bool(3), float64(19), int64(2), object(14)
# memory usage: 49.8+ MB

# %%
full_tracks.to_csv('lifetime_spotify_tracks.csv', index=False)
